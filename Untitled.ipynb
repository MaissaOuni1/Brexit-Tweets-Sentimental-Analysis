# %%
def get_tweets_dataset(query_search, until_date, max_tweets):
    import pandas as pd
    import GetOldTweets3 as got
    tweets = []
    for word in query_search.split():
        tweetCriteria = got.manager.TweetCriteria().setQuerySearch(word).setUntil(until_date).setMaxTweets(max_tweets)
        for tweet in got.manager.TweetManager.getTweets(tweetCriteria):
            if not tweet in tweets:
                tweets.append(tweet)
    hashs = []
    texts = []
    dates = []
    retweets = []
    favorites = []
    usernames = []
    for tweet in tweets:
        hash_positions = [pos for pos, char in enumerate(tweet.hashtags) if char == '#']
        tweet_hashs = []
        texts.append(tweet.text)
        dates.append(tweet.date)
        retweets.append(tweet.retweets)
        favorites.append(tweet.favorites)
        usernames.append(tweet.username)
        for ind in hash_positions:
            if tweet.hashtags.find(' ', ind) == -1:
                word = tweet.hashtags[ind:]
                tweet_hashs.append(word)
            else:
                end = tweet.hashtags.find(' ', ind)
                word = tweet.hashtags[ind:end]
                tweet_hashs.append(word)
        hashs.append(tweet_hashs)
    return pd.DataFrame({"Username":usernames, "Date":dates, "Favorites":favorites, "Retweets":retweets, "Hashtags":hashs, "Text":texts})

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    import re
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analyze_sentiment(tweet):
    from textblob import TextBlob
    analysis = TextBlob(clean_tweet(tweet))
    return analysis.sentiment.polarity

# %matplotlib inline

# %%
# David Cameron promised an in/out EU referendum on 23rd January 2013
referendum_campaign_dataset = get_tweets_dataset("#cameron #referendum", "2013-01-25", 1500)
referendum_campaign_dataset.head(10)
referendum_campaign_dataset.to_csv("referendum_campaign_dataset.csv", index=False)
# Out:
#           Username                      Date  Favorites  Retweets  \
# 0    jonathanfryer 2013-01-24 23:52:14+00:00          0         4
# 1      mirnalavado 2013-01-24 23:51:22+00:00          0         0
# 2        AndyP1000 2013-01-24 23:48:38+00:00          0         0
# 3  Dequinceyschimp 2013-01-24 23:45:43+00:00          0         0
# 4         SamIngro 2013-01-24 23:45:14+00:00          0         0
# 5    jonathanfryer 2013-01-24 23:45:10+00:00          0         1
# 6   scarletmonahan 2013-01-24 23:43:44+00:00          0         1
# 7   Ashley_Bullard 2013-01-24 23:42:33+00:00          0         0
# 8       RyoungRory 2013-01-24 23:39:43+00:00          0         0
# 9   scarletmonahan 2013-01-24 23:37:43+00:00          0         0
#
#                                             Hashtags  \
# 0                               [#Cameron, #UK, #EU]
# 1                 [#Francia, #Alemania, #Cameron, #]
# 2                           [#Cameron, #Merkel, #EU]
# 3                                         [#Cameron]
# 4                       [#Cameron, #Jordan, #Saints]
# 5                     [#bbctw, #Cameron, #EU, #UKIP]
# 6  [#williamhague, #satire, #politics, #cameron, ...
# 7  [#bbctw, #politics, #UKPolitics, #Conservative...
# 8      [#Cameron, #davos, #bbcqt, #bbcdailypolitics]
# 9  [#McDonalds, #satire, #THATCHER, #politics, #c...
#
#                                                 Text
# 0  Shirley Williams is right that #Cameron is on ...
# 1  #Francia y #Alemania responden a #Cameron que ...
# 2  #Cameron is the biggest loser in british polit...
# 3  @Neilovichi It's not the Tory way. Besides #Ca...
# 4  Feel bad for #Cameron #Jordan , spent all seas...
# 5  So who does #bbctw get to comment on #Cameron ...
# 6  #williamhague Spawn Drone! http:// yfrog.com/4...
# 7  Wow the innuendo on #bbctw this evening is ver...
# 8  #Cameron @#davos : 'Come to Britain we are cut...
# 9  George Osborne is truly the leader of a heard ...

# %%
import pandas as pd
referendum_campaign_dataset = pd.read_csv("referendum_campaign_dataset.csv")

# %%
import numpy as np
referendum_campaign_dataset['Sentiment'] = np.array([ analyze_sentiment(text) for text in referendum_campaign_dataset['Text'] ])
referendum_campaign_dataset.head(10)
# Out:
#           Username                       Date  Favorites  Retweets  \
# 0    jonathanfryer  2013-01-24 23:52:14+00:00          0         4
# 1      mirnalavado  2013-01-24 23:51:22+00:00          0         0
# 2        AndyP1000  2013-01-24 23:48:38+00:00          0         0
# 3  Dequinceyschimp  2013-01-24 23:45:43+00:00          0         0
# 4         SamIngro  2013-01-24 23:45:14+00:00          0         0
# 5    jonathanfryer  2013-01-24 23:45:10+00:00          0         1
# 6   scarletmonahan  2013-01-24 23:43:44+00:00          0         1
# 7   Ashley_Bullard  2013-01-24 23:42:33+00:00          0         0
# 8       RyoungRory  2013-01-24 23:39:43+00:00          0         0
# 9   scarletmonahan  2013-01-24 23:37:43+00:00          0         0
#
#                                             Hashtags  \
# 0                         ['#Cameron', '#UK', '#EU']
# 1         ['#Francia', '#Alemania', '#Cameron', '#']
# 2                     ['#Cameron', '#Merkel', '#EU']
# 3                                       ['#Cameron']
# 4                 ['#Cameron', '#Jordan', '#Saints']
# 5             ['#bbctw', '#Cameron', '#EU', '#UKIP']
# 6  ['#williamhague', '#satire', '#politics', '#ca...
# 7  ['#bbctw', '#politics', '#UKPolitics', '#Conse...
# 8  ['#Cameron', '#davos', '#bbcqt', '#bbcdailypol...
# 9  ['#McDonalds', '#satire', '#THATCHER', '#polit...
#
#                                                 Text  Sentiment
# 0  Shirley Williams is right that #Cameron is on ...   0.285714
# 1  #Francia y #Alemania responden a #Cameron que ...   0.000000
# 2  #Cameron is the biggest loser in british polit...   0.000000
# 3  @Neilovichi It's not the Tory way. Besides #Ca...  -0.200000
# 4  Feel bad for #Cameron #Jordan , spent all seas...  -0.191111
# 5  So who does #bbctw get to comment on #Cameron ...  -1.000000
# 6  #williamhague Spawn Drone! http:// yfrog.com/4...   0.000000
# 7  Wow the innuendo on #bbctw this evening is ver...   0.150000
# 8  #Cameron @#davos : 'Come to Britain we are cut...  -0.102500
# 9  George Osborne is truly the leader of a heard ...   0.000000

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(18, 8), subplot_kw=dict(aspect="equal"))
ax.axis("equal")

data = [
    100 * round(sum(referendum_campaign_dataset['Sentiment'] < 0) / len(referendum_campaign_dataset['Sentiment']), 5),
    100 * round(sum(referendum_campaign_dataset['Sentiment'] == 0) / len(referendum_campaign_dataset['Sentiment']), 5),
    100 * round(sum(referendum_campaign_dataset['Sentiment'] > 0) / len(referendum_campaign_dataset['Sentiment']), 5)
]
labels = ['Negative','Neutral','Positive']

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.35), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.5", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate("{:.2f}%".format(data[i]) + " " + labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.2*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("David Cameron's Campaign Tweets Sentiment Analysis")
plt.show()

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

text = " ".join(txt for txt in referendum_campaign_dataset['Text'])

stopwords = set(STOPWORDS)
stopwords.update(["bit", "pic", "twitter", "il", "html", "https", "de", "la", "en", "van", "le", "maintien", "maar", "gamble", "et", "en"])
wordcloud = WordCloud(height=1080, stopwords=stopwords, width=1920, background_color="white").generate(text)

plt.figure(figsize=(24, 12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

wordcloud.to_file("cameron_campaign.png");

# %%
# Conservatives & David Cameron won the 2015 UK elections
elections_dataset = get_tweets_dataset("#conservative #cameron #elections2015 #referendum", "2015-05-09", 1500)
elections_dataset.to_csv("elections_dataset.csv", index=False)
elections_dataset = pd.read_csv("elections_dataset.csv")
elections_dataset['Sentiment'] = np.array([ analyze_sentiment(text) for text in elections_dataset['Text'] ])
elections_dataset.head(10)
# Out:
#          Username                       Date  Favorites  Retweets  \
# 0     DrTeckKhong  2015-05-08 23:55:55+00:00          0         0
# 1  ThomasEvansSDP  2015-05-08 23:55:23+00:00          3         1
# 2     DrTeckKhong  2015-05-08 23:53:27+00:00          0         1
# 3   Ramblintweets  2015-05-08 23:51:58+00:00          0         0
# 4   FrankieHall04  2015-05-08 23:48:13+00:00          0         0
# 5  therealmrhenry  2015-05-08 23:48:02+00:00          0         0
# 6    DavidPrebble  2015-05-08 23:46:43+00:00          0         0
# 7     nathanbroon  2015-05-08 23:46:02+00:00          0         0
# 8        cianb800  2015-05-08 23:42:06+00:00          0         0
# 9   theredandblue  2015-05-08 23:41:35+00:00          0         0
#
#                                             Hashtags  \
# 0                                  ['#Conservative']
# 1    ['#GE2015', '#Labour', '#Conservative', '#SNP']
# 2                                  ['#Conservative']
# 3                                  ['#Conservative']
# 4  ['#Conservative', '#true', '#blue', '#deliver'...
# 5                                  ['#Conservative']
# 6                       ['#Conservative', '#GE2015']
# 7                                  ['#Conservative']
# 8                                  ['#Conservative']
# 9                       ['#GE2015', '#Conservative']
#
#                                                 Text  Sentiment
# 0  Election of #Conservative Anne Bond (right) as...   0.285714
# 1  A few things to seriously ponder with regards ...  -0.266667
# 2  Election of #Conservative Bhupendra Dave (2nd ...   0.000000
# 3  Theresa May has confirmed on Twitter that she ...   0.400000
# 4  10 #Conservative promises.. http://www. telegr...   0.116667
# 5  There was an article that showed the #Conserva...   0.187500
# 6  Congratulations @DavidCameron_MP excellent cam...   0.666667
# 7  @IanHaigh77 not really. The #Conservative part...  -0.100000
# 8  #Conservative delighted @David_Cameron will re...   0.700000
# 9  The British Left would've unhesitatingly accep...   0.025000

# %%
fig, ax = plt.subplots(figsize=(18, 8), subplot_kw=dict(aspect="equal"))
ax.axis("equal")

data = [
    100 * round(sum(elections_dataset['Sentiment'] < 0) / len(elections_dataset['Sentiment']), 5),
    100 * round(sum(elections_dataset['Sentiment'] == 0) / len(elections_dataset['Sentiment']), 5),
    100 * round(sum(elections_dataset['Sentiment'] > 0) / len(elections_dataset['Sentiment']), 5)
]
labels = ['Negative','Neutral','Positive']

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.35), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.5", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate("{:.2f}%".format(data[i]) + " " + labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.2*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("David Cameron's Party Winning the 2015 UK Elections")
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import networkx as nx
G = nx.Graph()
G.clear()

# %%
hashtags = []
for hash_list in elections_dataset.values[:,4]:
    hashtags.extend(hash_list[2:-2].split("', '"))
from collections import OrderedDict
hashtags = list(OrderedDict.fromkeys(hashtags))
for hashtag in hashtags:
    G.add_node(hashtag.lower(), name=hashtag.lower())

edges = []
for hash_list in elections_dataset.values[:,4]:
    hash_list = hash_list[2:-2].split("', '")
    if len(hash_list) > 1:
        for i in range(0,len(hash_list)):
            for j in range(i+1,len(hash_list)):
                edges.append([hash_list[i].lower(), hash_list[j].lower()])
for edge in edges:
    G.add_edge(edge[0], edge[1])

# %%
fig, ax = plt.subplots(figsize=(24, 12))
ax.axis('equal')
width = 0.15

cm = plt.get_cmap("tab20c")
cout = cm(np.arange(3)*4)
vals_out = [len([d for d in G.degree if d[1] <= 1]),
            len([d for d in G.degree if d[1] <= 20 and d[1] > 1]),
            len([d for d in G.degree if d[1] > 20])
           ]
pie, _ = ax.pie(vals_out, radius=1, labels=["1 or less", "2 to 20", "More than 20"], colors=cout)
plt.setp( pie, width=width, edgecolor='white')

cin = cm(np.array([1,2,5,6,9,10]))
labels = list(map("".join, zip(["0 tweets", "1 tweet", "Less than 10", "More than 10", "Less than 100", "More than 100"])))
vals_in = [len([d for d in G.degree if d[1] == 0]),
           len([d for d in G.degree if d[1] == 1]),
           len([d for d in G.degree if d[1] > 1 and d[1] <= 10]),
           len([d for d in G.degree if d[1] > 10 and d[1] <= 20 ]),
           len([d for d in G.degree if d[1] > 20 and d[1] <= 100]),
           len([d for d in G.degree if d[1] > 100])
          ]
pie2, _ = ax.pie(vals_in, radius=1-width, labels=labels,
                                      labeldistance=0.7, colors=cin)
plt.setp( pie2, width=width, edgecolor='white')
plt.title("Hashtags tweet appearances by degree")
plt.show()
print("Les hashtags apparant dans plus que 20 tweets et moins que 100 tweets sont de", len([d for d in G.degree if d[1] <= 100 and d[1] > 20]), "tweets.")
print("Les hashtags apparant dans plus que 100 tweets sont de", len([d for d in G.degree if d[1] > 100]), "tweets.")
# Out:
# Les hashtags apparant dans plus que 20 tweets et moins que 100 tweets sont de 86 tweets.
# Les hashtags apparant dans plus que 100 tweets sont de 14 tweets.

# %% [markdown]
# <h4>Suivant notre graphique visualisé, on a décidé d'éliminer les hashtags apparant dans 20 ou moins tweets pour étudier les relations plus influancants entre les hashtags restant.</h4>

# %%
G.remove_nodes_from([d[0] for d in G.degree if d[1] <= 20 ])

# %%
print("Les noeuds/hashtags restant dans notre graph sont de", len([d for d in G.degree]), "noeuds.")
# Out:
# Les noeuds/hashtags restant dans notre graph sont de 100 noeuds.

# %%
nx.draw(G, node_size=1600, cmap=plt.cm.Reds,
        node_color=range(len(G)), pos=nx.random_layout(G), with_labels=True)

# %% [markdown]
# <h4>Vu que même en essayant beaucoup de 'layouts' du module 'networkx' et on n'arrive encore pas à identifier nos noeuds, on va se mener du logiciel Gephi pour la visualisation de notre graph</h4>

# %%
nx.write_gexf(G, "elections_2015.gexf")

# %% [markdown]
# <center>
#     <strong>Hashtags shared between Tweets</strong>
#     <img src="Elections_2015_Graph_Analysis.png">
# </center>

# %%
# The UK have ran the BREXIT referendum and cameron resigned from PM post
brexit_cameron_resign_dataset = get_tweets_dataset("#brexit #cameron", "2016-06-26", 1500)
brexit_cameron_resign_dataset.to_csv("brexit_cameron_resign_dataset.csv", index=False)
brexit_cameron_resign_dataset = pd.read_csv("brexit_cameron_resign_dataset.csv")
brexit_cameron_resign_dataset['Sentiment'] = np.array([ analyze_sentiment(text) for text in brexit_cameron_resign_dataset['Text'] ])
brexit_cameron_resign_dataset.head(10)
# Out:
#           Username                       Date  Favorites  Retweets  \
# 0  DollarVigilante  2016-06-25 23:59:59+00:00         18        10
# 1          747Gold  2016-06-25 23:59:58+00:00          0         0
# 2    ARMAKdeODELOT  2016-06-25 23:59:58+00:00          2         0
# 3         drwilcox  2016-06-25 23:59:57+00:00          1         0
# 4       veryFatcat  2016-06-25 23:59:57+00:00          1         1
# 5        serenacwy  2016-06-25 23:59:55+00:00          0         0
# 6        4589roger  2016-06-25 23:59:54+00:00          1         1
# 7        mitchr777  2016-06-25 23:59:53+00:00          0         0
# 8         Eduflack  2016-06-25 23:59:51+00:00          3        21
# 9     GoldEagleCom  2016-06-25 23:59:51+00:00          3         3
#
#                                          Hashtags  \
# 0                       ['#Brexit', '#Investing']
# 1                                     ['#Brexit']
# 2                                     ['#Brexit']
# 3                                     ['#Brexit']
# 4                                     ['#Brexit']
# 5               ['#EUref', '#Brexit', '#regexit']
# 6           ['#Boris', '#Gove', '#Brexit', '#EU']
# 7  ['#Brexit', '#isis', '#WriteAPoemAboutBrexit']
# 8                                     ['#Brexit']
# 9                 ['#Gold', '#Silver', '#brexit']
#
#                                                 Text  Sentiment
# 0  You Could Have Prospered Greatly from the #Bre...      0.800
# 1  I liked a @YouTube video from @lack78 http:// ...      0.300
# 2  Desmontando la Historia Oficial del Brexit + 1...      0.000
# 3  Pretty apt #Brexit analogy: pic.twitter.com/XM...      0.425
# 4  Don't forget that the #Brexit is just a vote, ...      0.000
# 5  . @timminchin tweets are spot on #EUref #Brexi...      0.000
# 6  There are liars and then there’s #Boris Johnso...      0.000
# 7  Roses are red as is blood we vote #Brexit #isi...      0.000
# 8  In recognition of #Brexit , my redeye flight m...      0.000
# 9  #Gold And #Silver Prices This Week #brexit htt...      0.000

# %%
fig, ax = plt.subplots(figsize=(18, 8), subplot_kw=dict(aspect="equal"))
ax.axis("equal")

data = [
    100 * round(sum(brexit_cameron_resign_dataset['Sentiment'] < 0) / len(brexit_cameron_resign_dataset['Sentiment']), 5),
    100 * round(sum(brexit_cameron_resign_dataset['Sentiment'] == 0) / len(brexit_cameron_resign_dataset['Sentiment']), 5),
    100 * round(sum(brexit_cameron_resign_dataset['Sentiment'] > 0) / len(brexit_cameron_resign_dataset['Sentiment']), 5)
]
labels = ['Negative','Neutral','Positive']

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.35), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.5", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate("{:.2f}%".format(data[i]) + " " + labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.2*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("Referendum ends and Brexit is on its way")
plt.show()

# %%
text = " ".join(txt for txt in brexit_cameron_resign_dataset['Text'])

stopwords = set(STOPWORDS)
stopwords.update(["bit", "pic", "twitter", "il", "html", "https", "de", "la", "en", "van", "le", "maintien", "maar", "gamble", "et", "en"])
wordcloud = WordCloud(height=1080, stopwords=stopwords, width=1920, background_color="white").generate(text)

plt.figure(figsize=(24, 12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

wordcloud.to_file("brexit_on_its_way.png");

# %%
# Brexit is finally effective
brexit_effective_dataset = get_tweets_dataset("#cameron #brexit", "2017-03-31", 1500)
brexit_effective_dataset.to_csv("brexit_effective_dataset.csv", index=False)
brexit_effective_dataset = pd.read_csv("brexit_effective_dataset.csv")
brexit_effective_dataset['Sentiment'] = np.array([ analyze_sentiment(text) for text in brexit_effective_dataset['Text'] ])
brexit_effective_dataset.head(10)
# Out:
#        Username                       Date  Favorites  Retweets  \
# 0  aliaswhoever  2017-03-30 23:59:59+00:00          0         0
# 1  MrBrandonHee  2017-03-30 23:59:57+00:00          0         0
# 2      agegomez  2017-03-30 23:59:57+00:00          0         0
# 3      TomJ8899  2017-03-30 23:59:48+00:00          0         0
# 4   WriterWeegs  2017-03-30 23:59:34+00:00          0         0
# 5    wiganshale  2017-03-30 23:59:34+00:00          0         0
# 6        hopbin  2017-03-30 23:59:33+00:00          0         0
# 7     alexielsi  2017-03-30 23:59:00+00:00          0         0
# 8    BrexitDays  2017-03-30 23:58:04+00:00          1         0
# 9     Sergi0068  2017-03-30 23:57:57+00:00          0         0
#
#                                             Hashtags  \
# 0  ['#BBC', '#against', '#Brexit', '#bullshitbaff...
# 1                                        ['#brexit']
# 2                                        ['#brexit']
# 3                    ['#EUref', '#Leave', '#Brexit']
# 4  ['#Passports', '#Brexit', '#Color', '#Blue', '...
# 5                                        ['#brexit']
# 6                              ['#Trump', '#Brexit']
# 7                        ['#brexit', '#poundtoeuro']
# 8                          ['#BexitDays', '#Brexit']
# 9                                        ['#Brexit']
#
#                                                 Text  Sentiment
# 0  #BBC urged to stand firm #against accusations ...  -0.200000
# 1  Larry doesn't give a fuck about #brexit Larry ...  -0.400000
# 2  Gobierno francés aseguró que negociación del “...   0.000000
# 3  And that was Tory Manifesto. What's that got t...  -0.400000
# 4  Interesting. #Passports #Brexit #Color #Blue #...   0.250000
# 5  True, except for Germany, who're bothered, bec...   0.116667
# 6  #Trump and his #Brexit disaster. https://www. ...   0.000000
# 7  Yen gains as risky assets lose traction, pound...  -0.333333
# 8  #BexitDays How the world sees #Brexit Britain ...   0.000000
# 9  I have given them already. IN #Brexit WM says ...   0.000000

# %%
fig, ax = plt.subplots(figsize=(18, 8), subplot_kw=dict(aspect="equal"))
ax.axis("equal")

data = [
    100 * round(sum(brexit_effective_dataset['Sentiment'] < 0) / len(brexit_effective_dataset['Sentiment']), 5),
    100 * round(sum(brexit_effective_dataset['Sentiment'] == 0) / len(brexit_effective_dataset['Sentiment']), 5),
    100 * round(sum(brexit_effective_dataset['Sentiment'] > 0) / len(brexit_effective_dataset['Sentiment']), 5)
]
labels = ['Negative','Neutral','Positive']

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.35), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.5", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate("{:.2f}%".format(data[i]) + " " + labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.2*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("Brexit's Effective Twitter Analysis")
plt.show()

# %%
brexit_effective_dataset.sort_values(["Retweets", "Favorites"], ascending=False)
brexit_effective_dataset_retweeted = brexit_effective_dataset.drop(brexit_effective_dataset[brexit_effective_dataset.Retweets <= 10].index)
brexit_effective_dataset_retweeted.sort_values(["Retweets", "Favorites"], ascending=False).head(10)
# Out:
#              Username                       Date  Favorites  Retweets  \
# 160        drbenwhite  2017-03-30 23:35:49+00:00        585      1059
# 850       CostlyWrath  2017-03-30 22:32:37+00:00        520       331
# 863        sawdoctors  2017-03-30 22:31:40+00:00        149        64
# 1206  AngusMacNeilSNP  2017-03-30 22:11:34+00:00         70        57
# 577    LondonEconomic  2017-03-30 22:55:53+00:00         39        49
# 972      EuropeElects  2017-03-30 22:24:37+00:00         50        47
# 104     SuzanneEvans1  2017-03-30 23:43:33+00:00         84        45
# 855        Paul_D1963  2017-03-30 22:32:19+00:00        110        42
# 567   HerbertEkweEkwe  2017-03-30 22:56:41+00:00          0        41
# 922             DVATW  2017-03-30 22:28:26+00:00         75        30
#
#                                                Hashtags  \
# 160                           ['#Brexit', '#NHScrisis']
# 850       ['#brexit', '#Article50', '#GreatRepealBill']
# 863                                         ['#brexit']
# 1206                              ['#bbcqt', '#brexit']
# 577                               ['#BBCQT', '#brexit']
# 972                                         ['#Brexit']
# 104                                         ['#Brexit']
# 855                                         ['#brexit']
# 567   ['#Biafra', '#predates', '#Brexit', '#50years'...
# 922           ['#UKIP', '#Corbyn', '#Brexit', '#bbcqt']
#
#                                                    Text  Sentiment
# 160   Whilst you lot are all obsessed with #Brexit ,...  -0.218519
# 850   Let me reiterate: We won't be silenced. We won...   0.000000
# 863                  #brexit pic.twitter.com/CK2pOsJPUp   0.000000
# 1206  #bbcqt post #brexit ref ...Ruth Davidson was s...  -0.071429
# 577   Quiz: Just for fun who said these following st...   0.150000
# 972   Italy, Winpoll poll: Eurozone Membership Refer...   0.000000
# 104             Yep. #Brexit pic.twitter.com/Wbtc850euU   0.000000
# 855   Labour for 35 years as voter, member & candida...   0.250000
# 567   #Biafra #predates #Brexit by #50years http:// ...   0.000000
# 922   BBC narrative #UKIP are finished #Corbyn can w...   0.800000

# %%
G1 = nx.Graph()
G1.clear()
indexs = []
indexs.extend(brexit_effective_dataset_retweeted.index)
for ind in indexs:
    G1.add_node(ind, text=clean_tweet(brexit_effective_dataset_retweeted.loc[[ind]].values[0][5]), retweets=brexit_effective_dataset_retweeted.loc[[ind]].values[0][3])

# %%
edges = []
j = 0
for ind in indexs:
    j = j+1
    item = brexit_effective_dataset_retweeted.loc[[ind]].values[0]
    hash_list = item[4][2:-2].split("', '")
    for l in hash_list:
        l = l.lower()
    for i in range(j,len(brexit_effective_dataset_retweeted)-1):
        other_hash_list = brexit_effective_dataset_retweeted.iloc[[i]].values[0][4][2:-2].split("', '")
        for l in other_hash_list:
            l = l.lower()
        if len(list(set(hash_list) & set(other_hash_list))) > 0:
            edges.append((ind, brexit_effective_dataset_retweeted.iloc[[i]].index[0], len(list(set(hash_list) & set(other_hash_list)))))
G1.add_weighted_edges_from(edges)

# %%
nx.draw(G1, node_size=1600, cmap=plt.cm.Blues,
        node_color=range(len(G1)), pos=nx.random_layout(G1), with_labels=True)

# %%
nx.write_gexf(G1, "brexit_effective.gexf")
fh=open("test.adjlist",'wb')
nx.write_adjlist(G1, fh)

# %% [markdown]
# <center>
#     <strong>Retweeted tweets and shared hashtags</strong>
#     <img src="Brexit_Effective_Graph_Analysis.png">
# </center>

# %%
# Identify which tweets are the centers of interest
brexit_effective_dataset_retweeted.loc[[160]] # most retweeted is a negative one
# Out:
#        Username                       Date  Favorites  Retweets  \
# 160  drbenwhite  2017-03-30 23:35:49+00:00        585      1059
#
#                       Hashtags  \
# 160  ['#Brexit', '#NHScrisis']
#
#                                                   Text  Sentiment
# 160  Whilst you lot are all obsessed with #Brexit ,...  -0.218519

# %%
brexit_effective_dataset_retweeted.loc[[1164]]
brexit_effective_dataset_retweeted.loc[[1085]]
brexit_effective_dataset_retweeted.loc[[1057]]
brexit_effective_dataset_retweeted.loc[[1359]]
brexit_effective_dataset_retweeted.loc[[1164]]
brexit_effective_dataset_retweeted.loc[[1211]]
brexit_effective_dataset_retweeted.loc[[1252]]
brexit_effective_dataset_retweeted.loc[[1277]]
brexit_effective_dataset_retweeted.loc[[910]]
# Out:
#             Username                       Date  Favorites  Retweets  \
# 910  shelleypetersen  2017-03-30 22:28:45+00:00          0        18
#
#                                               Hashtags  \
# 910  ['#healthinnovations', '#pharma', '#banking', ...
#
#                                                   Text  Sentiment
# 910  7 key moments from Germany’s Brexit debate htt...        0.0

# %%
from datetime import timedelta, datetime
from forex_python.converter import CurrencyRates
c = CurrencyRates()
i=0
v=[]
t=[]
while i!=200:
    v.append(c.get_rate('GBP','USD',datetime(2016, 6, 22, 18, 36, 28, 151012)+timedelta(i)))
    t.append(datetime(2016, 6, 22, 18, 36, 28, 151012)+timedelta(i))
    i=i+1
df = pd.DataFrame()
df['timestamp'] = t
df['currency rate'] =v
df.tail(10)
tcurr = pd.Series(data=df['currency rate'].values, index=df['timestamp'])
fig, ax = plt.subplots()
tcurr.plot(figsize=(20,4), color='r')
ax.set_title('Currency Charts: GBP to USD since BREXIT vote')
# Out:
# Text(0.5,1,'Currency Charts: GBP to USD since BREXIT vote')

# %%
# David Cameron comes back into politics (ukip = UK independance party)
cameron_back_dataset = get_tweets_dataset("#davidcameron #ukip", "2018-11-03", 1500)
cameron_back_dataset.to_csv("cameron_back_dataset.csv", index=False)
cameron_back_dataset = pd.read_csv("cameron_back_dataset.csv")
cameron_back_dataset['Sentiment'] = np.array([ analyze_sentiment(text) for text in cameron_back_dataset['Text'] ])
cameron_back_dataset.head(10)
# Out:
#           Username                       Date  Favorites  Retweets  \
# 0   KangarooCaught  2018-11-02 23:34:48+00:00          0         0
# 1        SwotTyler  2018-11-02 23:08:22+00:00          0         0
# 2     johnamcgowan  2018-11-02 22:53:31+00:00          0         0
# 3     MadeleinaKay  2018-11-02 22:53:15+00:00        167        28
# 4      TheHubyster  2018-11-02 22:29:30+00:00          0         0
# 5     ElCorbynista  2018-11-02 22:25:50+00:00          1         1
# 6  markalexander_1  2018-11-02 22:19:20+00:00          0         0
# 7       shirlsmart  2018-11-02 22:11:08+00:00          4         0
# 8     ElCorbynista  2018-11-02 22:09:25+00:00          3         0
# 9  sarahofthenorth  2018-11-02 22:03:23+00:00          4         0
#
#                                             Hashtags  \
# 0                 ['#MartinRowson', '#DavidCameron']
# 1                                  ['#davidcameron']
# 2                                  ['#davidcameron']
# 3                                  ['#DavidCameron']
# 4                   ['#thelastleg', '#davidcameron']
# 5                                  ['#DavidCameron']
# 6                   ['#DavidCameron', '#MarinaHyde']
# 7         ['#davidcameron', '#ToriesOut', '#Brexit']
# 8                                  ['#DavidCameron']
# 9  ['#davidcameron', '#satire', '#cartoon', '#bre...
#
#                                                 Text  Sentiment
# 0  #MartinRowson on #DavidCameron 's rumoured pol...   0.000000
# 1  one for #davidcameron https://www. youtube.com...   0.000000
# 2  Seriously David Cameron, stay in your fucking ...  -0.144444
# 3  The more I reflect upon it Given all the fabul...   0.444444
# 4         Fuck it, I'm off #thelastleg #davidcameron  -0.400000
# 5  The saddest thing is that #DavidCameron is sti...   0.000000
# 6  #DavidCameron , get back in your hut. You’ve d...   0.000000
# 7  NOOOOOOOOO!!!! Just No...thanks. Apparently he...   0.000000
# 8  BREAKING: David Cameron says goodbye to loved ...   0.233333
# 9  Here's a little cartoon I did today in light o...   0.103125

# %%
fig, ax = plt.subplots(figsize=(18, 8), subplot_kw=dict(aspect="equal"))
ax.axis("equal")

data = [
    100 * round(sum(cameron_back_dataset['Sentiment'] < 0) / len(cameron_back_dataset['Sentiment']), 5),
    100 * round(sum(cameron_back_dataset['Sentiment'] == 0) / len(cameron_back_dataset['Sentiment']), 5),
    100 * round(sum(cameron_back_dataset['Sentiment'] > 0) / len(cameron_back_dataset['Sentiment']), 5)
]
labels = ['Negative','Neutral','Positive']

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.35), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.5", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate("{:.2f}%".format(data[i]) + " " + labels[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.2*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("Cameron is back?")
plt.show()

# %% [markdown]
# Why are people still thinking positively about him? Or let us say, why are still those who think positively about him? (50/50) Or another formula: Why are opinions still divided about David Cameron? After all what he caused of damage to the UK. What are the hopes for the UK with this man's return? Will he try to fix what he broked? And if so, what are the odds that he'd make it? Or will he just make it worst?

# %%
text = " ".join(txt for txt in cameron_back_dataset['Text'])

stopwords = set(STOPWORDS)
stopwords.update(["bit", "pic", "twitter", "il", "html", "https", "de", "la", "en", "van", "le", "maintien", "maar", "gamble", "et", "en"])
wordcloud = WordCloud(height=1080, stopwords=stopwords, width=1920, background_color="white").generate(text)

plt.figure(figsize=(24, 12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

wordcloud.to_file("cameron_back.png");
